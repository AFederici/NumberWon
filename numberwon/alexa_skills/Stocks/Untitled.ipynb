# %%
from stock_final import Stocks
from yahoo_finance import Share
from pprint import pprint
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import datetime as dt
from scipy.fftpack import idct, dct
import numpy as np
import itertools
from matplotlib.dates import DateFormatter, WeekdayLocator,DayLocator, MONDAY

# %%
s = Stocks()

# %%
m = pickle.load( open('tickers.pickle', "rb"))
len(m)
# Out:
# 500

# %%
l = pickle.load( open('selfticks.pickle', "rb"))
len(l)
# Out:
# 500

# %%
tickers = pickle.load( open('tickers.pickle', "rb"))
comps = pickle.load( open('comps.pickle', "rb"))
# comps = [
#         '3m co.',
#         'ace limited',
#         'abbott laboratories',
#         'abercrombie & fitch company a',
#         'accenture',
#         'adobe systems inc',
#         'advanced micro devices',
#         'aes corp',
#         'aetna inc',
#         'aflac inc',
#         'agilent technologies inc',
#         'agl resources inc.',
#         'air products & chemicals inc',
#         'airgas inc',
#         'akamai technologies inc',
#         'alcoa inc',
#         'alexion pharmaceuticals',
#         'allegheny technologies inc',
#         'allergan inc',
#         'allstate corp',
#         'alpha natural resources',
#         'altera corp',
#         'altria group inc',
#         'amazon',
#         'ameren corp',
#         'american electric power',
#         'american express co',
#         'american intl group inc',
#         'american tower corp a',
#         'ameriprise financial',
#         'amerisourcebergen corp',
#         'amgen inc',
#         'amphenol corp a',
#         'anadarko petroleum corp',
#         'analog devices inc',
#         'aon plc',
#         'apache corporation',
#         'apartment investment & mgmt',
#         'apollo group inc',
#         'apple',
#         'applied materials inc',
#         'archer-daniels-midland co',
#         'assurant inc',
#         'at&t inc',
#         'autodesk inc',
#         'automatic data processing',
#         'autonation inc',
#         'autozone inc',
#         'avalonbay communities, inc.',
#         'avery dennison corp',
#         'avon products',
#         'baker hughes inc',
#         'ball corp',
#         'bank of america corp',
#         'the bank of new york mellon corp.',
#         'bard (c.r.) inc.',
#         'baxter international inc.',
#         'bb&t corporation',
#         'beam inc.',
#         'becton dickinson',
#         'bed bath & beyond',
#         'bemis company',
#         'berkshire hathaway',
#         'best buy co. inc.',
#         'big lots inc.',
#         'biogen idec inc.',
#         'blackrock',
#         'block h&r',
#         'bmc software',
#         'boeing company',
#         'borgwarner',
#         'boston properties',
#         'boston scientific',
#         'bristol-myers squibb',
#         'broadcom corporation',
#         'brown-forman corporation',
#         'c. h. robinson worldwide',
#         'ca, inc.',
#         'cablevision systems corp.',
#         'cabot oil & gas',
#         'cameron international corp.',
#         'campbell soup',
#         'capital one financial',
#         'cardinal health inc.',
#         'carefusion',
#         'carmax inc',
#         'carnival corp.',
#         'caterpillar inc.',
#         'cbre group',
#         'cbs corp.',
#         'celgene corp.',
#         'centerpoint energy',
#         'centurylink inc',
#         'cerner',
#         'cf industries holdings inc',
#         'charles schwab',
#         'chesapeake energy',
#         'chevron corp.',
#         'chipotle mexican grill',
#         'chubb corp.',
#         'cigna corp.',
#         'cincinnati financial',
#         'cintas corporation',
#         'cisco systems',
#         'citigroup inc.',
#         'citrix systems',
#         'cliffs natural resources',
#         'clorox co.',
#         'cme group inc.',
#         'cms energy',
#         'coach inc.',
#         'coca cola co.',
#         'coca-cola enterprises',
#         'cognizant technology solutions',
#         'colgate-palmolive',
#         'comcast corp.',
#         'comerica inc.',
#         'computer sciences corp.',
#         'conagra foods inc.',
#         'conocophillips',
#         'consol energy inc.',
#         'consolidated edison',
#         'constellation brands',
#         'cooper industries',
#         'corning inc.',
#         'costco co.',
#         'coventry health care inc.',
#         'covidien plc',
#         'crown castle international corp.',
#         'csx corp.',
#         'cummins inc.',
#         'cvs caremark corp.',
#         'd. r. horton',
#         'danaher corp.',
#         'darden restaurants',
#         'davita inc.',
#         'dean foods',
#         'deere & co.',
#         'dell inc.',
#         'denbury resources inc.',
#         'dentsply international',
#         'devon energy corp.',
#         'devry, inc.',
#         'diamond offshore drilling',
#         'directv',
#         'discover financial services',
#         'discovery communications',
#         'dollar tree',
#         'dominion resources',
#         'donnelley (r.r.) & sons',
#         'dover corp.',
#         'dow chemical',
#         'dr pepper snapple group',
#         'dte energy co.',
#         'du pont (e.i.)',
#         'duke energy',
#         'dun & bradstreet',
#         'e-trade',
#         'eastman chemical',
#         'eaton corp.',
#         'ebay inc.',
#         'ecolab inc.',
#         'edison intl',
#         'edwards lifesciences',
#         'electronic arts',
#         'emc corp.',
#         'emerson electric',
#         'ensco plc',
#         'entergy corp.',
#         'eog resources',
#         'eqt corporation',
#         'equifax inc.',
#         'equity residential',
#         'estee lauder cos.',
#         'exelon corp.',
#         'expedia inc.',
#         'expeditors int',
#         'express scripts',
#         'exxon mobil corp.',
#         'f5 networks',
#         'family dollar stores',
#         'fastenal co',
#         'federated investors inc.',
#         'fedex corporation',
#         'fidelity national information services',
#         'fifth third bancorp',
#         'first horizon national',
#         'first solar inc',
#         'firstenergy corp',
#         'fiserv inc',
#         'flir systems',
#         'flowserve corporation',
#         'fluor corp.',
#         'fmc corporation',
#         'fmc technologies inc.',
#         'ford motor',
#         'forest laboratories',
#         'fossil, inc.',
#         'franklin resources',
#         'freeport-mcmoran cp & gld',
#         'frontier communications',
#         'gamestop corp.',
#         'gannett co.',
#         'gap',
#         'general dynamics',
#         'general electric',
#         'general mills',
#         'genuine parts',
#         'genworth financial inc.',
#         'gilead sciences',
#         'goldman sachs group',
#         'goodyear tire & rubber',
#         'google inc.',
#         'grainger (w.w.) inc.',
#         'halliburton co.',
#         'harley-davidson',
#         'harman intl',
#         'harris corporation',
#         'hartford financial svc.gp.',
#         'hasbro inc.',
#         'hcp inc.',
#         'health care reit',
#         'heinz (h.j.)',
#         'helmerich & payne',
#         'hess corporation',
#         'hewlett-packard',
#         'home depot',
#         'honeywell intl',
#         'hormel foods corp.',
#         'hospira inc.',
#         'host hotels & resorts',
#         'hudson city bancorp',
#         'humana inc.',
#         'huntington bancshares',
#         'illinois tool works',
#         'ingersoll-rand plc',
#         'integrys energy group inc.',
#         'intel corp.',
#         'intercontinentalexchange inc.',
#         'international bus. machines',
#         'international flav/frag',
#         'international game technology',
#         'international paper',
#         'interpublic group',
#         'intuit inc.',
#         'intuitive surgical inc.',
#         'invesco ltd.',
#         'iron mountain incorporated',
#         'jabil circuit',
#         'jacobs engineering group',
#         'jds uniphase corp.',
#         'johnson & johnson',
#         'johnson controls',
#         'joy global inc.',
#         'jpmorgan chase & co.',
#         'juniper networks',
#         'kellogg co.',
#         'keycorp',
#         'kimberly-clark',
#         'kimco realty',
#         'kinder morgan',
#         'kla-tencor corp.',
#         'kohls corp.',
#         'kraft foods inc-a',
#         'kroger co.',
#         'l-3 communications holdings',
#         'laboratory corp. of america holding',
#         'lam research',
#         'legg mason',
#         'leggett & platt',
#         'lennar corp.',
#         'leucadia national corp.',
#         'lexmark intl',
#         'life technologies',
#         'lilly (eli) & co.',
#         'limited brands inc.',
#         'lincoln national',
#         'linear technology corp.',
#         'lockheed martin corp.',
#         'loews corp.',
#         'lorillard inc.',
#         'lowes cos.',
#         'lsi corporation',
#         'm&t bank corp.',
#         'macys',
#         'marathon oil corp.',
#         'marathon petroleum',
#         'marriott',
#         'marsh & mclennan',
#         'masco corp.',
#         'mastercard inc.',
#         'mattel inc.',
#         'mccormick & co.',
#         'mcdonalds',
#         'mcgraw-hill',
#         'mckesson corp.',
#         'mead johnson',
#         'meadwestvaco corporation',
#         'medtronic inc.',
#         'merck & co.',
#         'metlife inc.',
#         'metropcs communications inc.',
#         'microchip technology',
#         'micron technology',
#         'microsoft corp.',
#         'molex inc.',
#         'molson coors brewing company',
#         'monsanto co.',
#         'monster beverage',
#         'moodys corp',
#         'morgan stanley',
#         'the mosaic company',
#         'motorola solutions inc.',
#         'murphy oil',
#         'mylan inc.',
#         'nabors industries ltd.',
#         'nasdaq omx group',
#         'national oilwell varco inc.',
#         'netapp',
#         'netflix inc.',
#         'newell rubbermaid co.',
#         'newfield exploration co',
#         'newmont mining corp. (hldg. co.)',
#         'news corporation',
#         'nextera energy resources',
#         'nike inc.',
#         'nisource inc.',
#         'noble corp',
#         'noble energy inc',
#         'nordstrom',
#         'norfolk southern corp.',
#         'northern trust corp.',
#         'northrop grumman corp.',
#         'northeast utilities',
#         'nrg energy',
#         'nucor corp.',
#         'nvidia',
#         'nyse euronext',
#         'o reilly automotive',
#         'occidental petroleum',
#         'omnicom group',
#         'oneok',
#         'oracle corp.',
#         'owens-illinois inc',
#         'paccar inc.',
#         'pall corp.',
#         'parker-hannifin',
#         'patterson companies',
#         'paychex inc.',
#         'peabody energy',
#         'penney (j.c.)',
#         'peoples united bank',
#         'pepco holdings inc.',
#         'pepsico inc.',
#         'perkinelmer',
#         'perrigo',
#         'pfizer inc.',
#         'pg&e corp.',
#         'philip morris international',
#         'phillips 66',
#         'pinnacle west capital',
#         'pioneer natural resources',
#         'pitney-bowes',
#         'plum creek timber co.',
#         'pnc financial services',
#         'polo ralph lauren corp.',
#         'ppg industries',
#         'ppl corp.',
#         'praxair inc.',
#         'precision castparts',
#         'priceline.com inc',
#         'principal financial group',
#         'procter & gamble',
#         'progressive corp.',
#         'prologis',
#         'prudential financial',
#         'public serv. enterprise inc.',
#         'public storage',
#         'pulte homes inc.',
#         'qep resources',
#         'quanta services',
#         'qualcomm',
#         'quest diagnostics',
#         'range resources corp.',
#         'raytheon',
#         'red hat inc.',
#         'regions financial corp.',
#         'republic services inc',
#         'reynolds american inc.',
#         'robert half international',
#         'rockwell automation inc.',
#         'rockwell collins',
#         'roper industries',
#         'ross stores inc.',
#         'rowan cos.',
#         'ryder system',
#         'safeway inc.',
#         'saic',
#         'salesforce.com',
#         'sandisk corporation',
#         'scana corp',
#         'schlumberger ltd.',
#         'scripps networks interactive inc.',
#         'seagate technology',
#         'sealed air corp.(new)',
#         'sears holdings corporation',
#         'sempra energy',
#         'sherwin-williams',
#         'sigma-aldrich',
#         'simon property group inc',
#         'slm corporation',
#         'smucker (j.m.)',
#         'snap-on inc.',
#         'southern co.',
#         'southwest airlines',
#         'southwestern energy',
#         'spectra energy corp.',
#         'sprint nextel corp.',
#         'st jude medical',
#         'stanley black & decker',
#         'staples inc.',
#         'starbucks corp.',
#         'starwood hotels & resorts',
#         'state street corp.',
#         'stericycle inc',
#         'stryker corp.',
#         'sunoco inc.',
#         'suntrust banks',
#         'symantec corp.',
#         'sysco corp.',
#         't. rowe price group',
#         'target corp.',
#         'te connectivity ltd.',
#         'teco energy',
#         'tenet healthcare corp.',
#         'teradata corp.',
#         'teradyne inc.',
#         'tesoro petroleum co.',
#         'texas instruments',
#         'textron inc.',
#         'the hershey company',
#         'the travelers companies inc.',
#         'thermo fisher scientific',
#         'tiffany & co.',
#         'time warner inc.',
#         'time warner cable inc.',
#         'titanium metals corp',
#         'tjx companies inc.',
#         'torchmark corp.',
#         'total system services',
#         'tripadvisor',
#         'tyson foods',
#         'tyco international',
#         'u.s. bancorp',
#         'union pacific',
#         'united health group inc.',
#         'united parcel service',
#         'united states steel corp.',
#         'united technologies',
#         'unum group',
#         'urban outfitters',
#         'v.f. corp.',
#         'valero energy',
#         'varian medical systems',
#         'ventas inc',
#         'verisign inc.',
#         'verizon',
#         'viacom inc.',
#         'visa inc.',
#         'vornado realty trust',
#         'vulcan materials',
#         'wal-mart stores',
#         'walgreen co.',
#         'disney',
#         'washington post co b',
#         'waste management inc.',
#         'waters corporation',
#         'watson pharmaceuticals',
#         'wellpoint inc.',
#         'wells fargo',
#         'western digital',
#         'western union co',
#         'weyerhaeuser corp.',
#         'whirlpool corp.',
#         'whole foods market',
#         'williams cos.',
#         'windstream corporation',
#         'wisconsin energy corporation',
#         'wpx energy, inc.',
#         'wyndham worldwide',
#         'wynn resorts ltd',
#         'xcel energy inc',
#         'xerox corp.',
#         'xilinx inc',
#         'xl capital',
#         'xylem inc.',
#         'yahoo inc.',
#         'yum! brands inc',
#         'zimmer holdings',
#         'zions bancorp']

# %%
s.new_company_list(comps, tickers)

# %%
s.comps
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f25e4a2ab6c4> in <module>()
# ----> 1 s.comps
#
# AttributeError: 'Stocks' object has no attribute 'comps'

# %%
s.populate()
# Out:
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'MMM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ACE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ABT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ANF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ACN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ADBE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AMD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AES', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AET', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AFL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'A', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GAS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'APD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ARG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AKAM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ALXN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ATI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AGN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ALL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ANR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ALTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'MO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AMZN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AEE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AEP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AXP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AIG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AMT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AMP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ABC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AMGN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'APH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'APC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ADI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AON', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'APA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AIV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'APOL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AAPL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AMAT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ADM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AIZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'T', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ADSK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ADP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AZO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AVB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AVY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'AVP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BHI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BLL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BAC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BCR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BAX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BBT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BEAM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BDX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BBBY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BMS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BRK.B', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BBY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BIG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BIIB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BLK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HRB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BMC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BWA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BXP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BSX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BMY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BRCM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BF.B', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CHRW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CVC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'COG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CAM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CPB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'COF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CAH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CFN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'KMX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CCL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CAT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CBG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CBS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CELG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CNP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CTL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CERN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'SCHW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CHK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CVX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CMG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CINF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CTAS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CSCO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'C', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CTXS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CLF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CLX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CME', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CMS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'COH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'KO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CCE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CTSH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CMCSA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CMA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CSC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CAG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'COP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ED', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'STZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CBE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GLW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'COST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CVH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'COV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CCI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CSX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CMI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'CVS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DHI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DHR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DRI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DVA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DELL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DNR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'XRAY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DVN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DTV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DFS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DISCA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DLTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'D', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'RRD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DOV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DOW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DPS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DTE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DUK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DNB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ETFC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EMN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ETN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EBAY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ECL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EIX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EMC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EMR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ESV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ETR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EOG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EQT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EFX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EQR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EXC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EXPE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'EXPD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ESRX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'XOM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FFIV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FDO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FAST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FII', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FDX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FIS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FITB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FHN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FSLR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FISV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FLIR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FLS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FLR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FMC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FTI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'F', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FRX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FOSL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'BEN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FCX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'FTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GME', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GCI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GPS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GIS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GPC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GNW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GILD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GOOG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'GWW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HAL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HOG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HAR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HRS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HIG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HAS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HCP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HCN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HNZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HES', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HPQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HON', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HRL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HSP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HCBK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HUM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HBAN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ITW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TEG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'INTC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ICE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IBM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IFF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IGT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IPG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'INTU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ISRG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IVZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'IRM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'JBL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'JEC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'JDSU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'JNJ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'JCI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'JOY', replacing with NaN.
# ...
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'STI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'SYMC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'SYY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TROW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TGT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TEL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'THC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TDC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TER', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TSO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TXN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TXT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'HSY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TRV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TMO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TIF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TWX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TWC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TIE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TJX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TMK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TSS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TRIP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TSN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'TYC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'USB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'UNP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'UNH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'UPS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'X', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'UTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'UNM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'URBN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VFC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VLO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VAR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VRSN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VIAB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'V', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VNO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'VMC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WMT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WAG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'DIS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WPO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WAT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WPI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WLP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WFC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WDC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WHR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WFM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WMB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WIN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WEC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WPX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WYN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'WYNN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'XEL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'XRX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'XLNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'XL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'XYL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'YHOO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'YUM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ZMH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py:177: SymbolWarning: Failed to read symbol: 'ZION', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-6-6d0756e6aa8f> in <module>()
# ----> 1 s.populate()
#
# C:\Users\student\NumberWon\numberwon\alexa_skills\Stocks\stock_final.py in populate(self)
#      61
#      62     def populate(self):
# ---> 63         self.datacollection(self.tickers)
#      64         print('1')
#      65         self.moving_averages(self.tickers)
#
# C:\Users\student\NumberWon\numberwon\alexa_skills\Stocks\stock_final.py in datacollection(self, tickers)
#      75         # We would like all available data from 01/01/2000 until 12/31/2016.
#      76         # User pandas_reader.data.DataReader to load the desired data. As simple as that.
# ---> 77         panel_data = data.DataReader(tickers, data_source, self.last_date, self.first_date)
#      78         # Getting just the adjusted closing prices. This will return a Pandas DataFrame
#      79         # The index in this DataFrame is the major index of the panel_data.
#
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     131                                  chunksize=25,
#     132                                  retry_count=retry_count, pause=pause,
# --> 133                                  session=session).read()
#     134
#     135     elif data_source == "enigma":
#
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     160             df = self._dl_mult_symbols(self.symbols.index)
#     161         else:
# --> 162             df = self._dl_mult_symbols(self.symbols)
#     163         return df
#     164
#
# C:\Users\student\Anaconda3\lib\site-packages\pandas_datareader\base.py in _dl_mult_symbols(self, symbols)
#     180         if len(passed) == 0:
#     181             msg = "No data fetched using {0!r}"
# --> 182             raise RemoteDataError(msg.format(self.__class__.__name__))
#     183         try:
#     184             if len(stocks) > 0 and len(failed) > 0 and len(passed) > 0:
#
# RemoteDataError: No data fetched using 'GoogleDailyReader'

# %%
# Out:
# {}

# %%
x = pickle.load( open('sp500.pickle', "rb"))

# %%
x
# Out:
# {}
