# %%
from stock_final import Stocks
from yahoo_finance import Share
from pprint import pprint
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import datetime as dt
from scipy.fftpack import idct, dct
import numpy as np
import itertools
from matplotlib.dates import DateFormatter, WeekdayLocator,DayLocator, MONDAY

# %%
s = Stocks()

# %%
tickers = pickle.load( open('tickers.pickle', "rb"))
comps = pickle.load( open('stocks.pickle', "rb"))

# %%
insert = list(zip(comps, tickers))
insert
# Out:
# [('three m', 'MMM'),
#  ('ace limited', 'ACE'),
#  ('abbott laboratories', 'ABT'),
#  ('abercrombie and fitch', 'ANF'),
#  ('abercrombie and fitchmpany', 'ACN'),
#  ('accenture', 'ADBE'),
#  ('adobe systems', 'AMD'),
#  ('advanced micro devices', 'AES'),
#  ('aes', 'AET'),
#  ('aetna', 'AFL'),
#  ('aflac', 'A'),
#  ('agilent technologies', 'GAS'),
#  ('agl resources', 'APD'),
#  ('air products and chemicals', 'ARG'),
#  ('airgas', 'AKAM'),
#  ('akamai technologies', 'AA'),
#  ('alcoa', 'ALXN'),
#  ('alexion pharmaceuticals', 'ATI'),
#  ('allegheny technologies', 'AGN'),
#  ('allergan', 'ALL'),
#  ('allstate', 'ANR'),
#  ('alpha natural resources', 'ALTR'),
#  ('altera', 'MO'),
#  ('altria group', 'AMZN'),
#  ('amazon', 'AEE'),
#  ('amazon.com', 'AEP'),
#  ('ameren', 'AXP'),
#  ('american electric power', 'AIG'),
#  ('american express', 'AMT'),
#  ('american intl group', 'AMP'),
#  ('american tower', 'ABC'),
#  ('american tower a', 'AMGN'),
#  ('ameriprise financial', 'APH'),
#  ('amerisourcebergen', 'APC'),
#  ('amgen', 'ADI'),
#  ('amphenol', 'AON'),
#  ('amphenol a', 'APA'),
#  ('anadarko petroleum', 'AIV'),
#  ('analog devices', 'APOL'),
#  ('aon plc', 'AAPL'),
#  ('apacheoration', 'AMAT'),
#  ('apartment investment & mgmt', 'ADM'),
#  ('apollo group', 'AIZ'),
#  ('apple', 'T'),
#  ('applied materials', 'ADSK'),
#  ('archer-daniels-midland', 'ADP'),
#  ('assurant', 'AN'),
#  ('at&t', 'AZO'),
#  ('autodesk', 'AVB'),
#  ('automatic data processing', 'AVY'),
#  ('autonation', 'AVP'),
#  ('autozone', 'BHI'),
#  ('avalonbaymmunities', 'BLL'),
#  ('avery dennison', 'BAC'),
#  ('avon products', 'BK'),
#  ('baker hughes', 'BCR'),
#  ('ball', 'BAX'),
#  ('bank of america', 'BBT'),
#  ('the bank of new york mellon', 'BEAM'),
#  ('bard', 'BDX'),
#  ('baxter international', 'BBBY'),
#  ('bb&toration', 'BMS'),
#  ('beam', 'BRK.B'),
#  ('becton dickinson', 'BBY'),
#  ('bed bath & beyond', 'BIG'),
#  ('bemismpany', 'BIIB'),
#  ('berkshire hathaway', 'BLK'),
#  ('best buy', 'HRB'),
#  ('big lots', 'BMC'),
#  ('biogen idec', 'BA'),
#  ('blackrock', 'BWA'),
#  ('block h&r', 'BXP'),
#  ('bmc software', 'BSX'),
#  ('boeingmpany', 'BMY'),
#  ('borgwarner', 'BRCM'),
#  ('boston properties', 'BF.B'),
#  ('boston scientific', 'CHRW'),
#  ('bristol-myers squibb', 'CA'),
#  ('broadcomoration', 'CVC'),
#  ('brown-formanoration', 'COG'),
#  ('c. h. robinson worldwide', 'CAM'),
#  ('ca', 'CPB'),
#  ('cablevision systems', 'COF'),
#  ('cabot oil and gas', 'CAH'),
#  ('cameron international', 'CFN'),
#  ('campbell soup', 'KMX'),
#  ('capital one financial', 'CCL'),
#  ('cardinal health', 'CAT'),
#  ('carefusion', 'CBG'),
#  ('carmax', 'CBS'),
#  ('carnival', 'CELG'),
#  ('caterpillar', 'CNP'),
#  ('cbre group', 'CTL'),
#  ('cbs', 'CERN'),
#  ('celgene', 'CF'),
#  ('centerpoint energy', 'SCHW'),
#  ('centurylink', 'CHK'),
#  ('cerner', 'CVX'),
#  ('cf industries holdings', 'CMG'),
#  ('charles schwab', 'CB'),
#  ('chesapeake energy', 'CI'),
#  ('chevron', 'CINF'),
#  ('chipotle mexican grill', 'CTAS'),
#  ('chubb', 'CSCO'),
#  ('cigna', 'C'),
#  ('cincinnati financial', 'CTXS'),
#  ('cintasoration', 'CLF'),
#  ('cisco systems', 'CLX'),
#  ('citigroup', 'CME'),
#  ('citrix systems', 'CMS'),
#  ('cliffs natural resources', 'COH'),
#  ('clorox', 'KO'),
#  ('cme group', 'CCE'),
#  ('cms energy', 'CTSH'),
#  ('coach', 'CL'),
#  ('coca cola', 'CMCSA'),
#  ('coca cola enterprises', 'CMA'),
#  ('cognizant technology solutions', 'CSC'),
#  ('colgate', 'CAG'),
#  ('comcast', 'COP'),
#  ('comerica', 'CNX'),
#  ('computer sciences', 'ED'),
#  ('conagra foods', 'STZ'),
#  ('conocophillips', 'CBE'),
#  ('consol energy', 'GLW'),
#  ('consolidated edison', 'COST'),
#  ('constellation brands', 'CVH'),
#  ('cooper industries', 'COV'),
#  ('corning', 'CCI'),
#  ('costco', 'CSX'),
#  ('coventry health care', 'CMI'),
#  ('covidien plc', 'CVS'),
#  ('crown castle international', 'DHI'),
#  ('csx', 'DHR'),
#  ('cummins', 'DRI'),
#  ('cvs caremark', 'DVA'),
#  ('d. r. horton', 'DF'),
#  ('danaher', 'DE'),
#  ('darden restaurants', 'DELL'),
#  ('davita', 'DNR'),
#  ('dean foods', 'XRAY'),
#  ('deere and co', 'DVN'),
#  ('dell', 'DV'),
#  ('denbury resources', 'DO'),
#  ('dentsply international', 'DTV'),
#  ('devon energy', 'DFS'),
#  ('devry', 'DISCA'),
#  ('diamond offshore drilling', 'DLTR'),
#  ('directv', 'D'),
#  ('discover financial services', 'RRD'),
#  ('discoverymmunications', 'DOV'),
#  ('dollar tree', 'DOW'),
#  ('dominion resources', 'DPS'),
#  ('donnelley and sons', 'DTE'),
#  ('r.r. and sons', 'DD'),
#  ('dover', 'DUK'),
#  ('dow chemical', 'DNB'),
#  ('dr pepper snapple group', 'ETFC'),
#  ('dte energy', 'EMN'),
#  ('du pont', 'ETN'),
#  ('duke energy', 'EBAY'),
#  ('dun and bradstreet', 'ECL'),
#  ('e trade', 'EIX'),
#  ('eastman chemical', 'EW'),
#  ('eaton', 'EA'),
#  ('ebay', 'EMC'),
#  ('ecolab', 'EMR'),
#  ('edison international', 'ESV'),
#  ('edwards lifesciences', 'ETR'),
#  ('electronic arts', 'EOG'),
#  ('emc', 'EQT'),
#  ('emerson electric', 'EFX'),
#  ('ensco plc', 'EQR'),
#  ('entergy', 'EL'),
#  ('eog resources', 'EXC'),
#  ('eqtoration', 'EXPE'),
#  ('equifax', 'EXPD'),
#  ('equity residential', 'ESRX'),
#  ('estee lauders', 'XOM'),
#  ('exelon', 'FFIV'),
#  ('expedia', 'FDO'),
#  ('expeditors international', 'FAST'),
#  ('express scripts', 'FII'),
#  ('exxon mobil', 'FDX'),
#  ('f5 networks', 'FIS'),
#  ('family dollar stores', 'FITB'),
#  ('fastenal', 'FHN'),
#  ('federated investors', 'FSLR'),
#  ('fedexoration', 'FE'),
#  ('fidelity national information services', 'FISV'),
#  ('fifth third bancorp', 'FLIR'),
#  ('first horizon national', 'FLS'),
#  ('first solar', 'FLR'),
#  ('firstenergy', 'FMC'),
#  ('fiserv', 'FTI'),
#  ('flir systems', 'F'),
#  ('flowserveoration', 'FRX'),
#  ('fluor', 'FOSL'),
#  ('fmcoration', 'BEN'),
#  ('fmc technologies', 'FCX'),
#  ('ford motor', 'FTR'),
#  ('forest laboratories', 'GME'),
#  ('fossil', 'GCI'),
#  ('franklin resources', 'GPS'),
#  ('freeport mcmoran cp and gld', 'GD'),
#  ('frontiermmunications', 'GE'),
#  ('gamestop', 'GIS'),
#  ('gannett', 'GPC'),
#  ('gap', 'GNW'),
#  ('the gap', 'GILD'),
#  ('general dynamics', 'GS'),
#  ('general electric', 'GT'),
#  ('general mills', 'GOOG'),
#  ('genuine parts', 'GWW'),
#  ('genworth financial', 'HAL'),
#  ('gilead sciences', 'HOG'),
#  ('goldman sachs', 'HAR'),
#  ('goldman sachs group', 'HRS'),
#  ('goodyear', 'HIG'),
#  ('goodyear tire and rubber', 'HAS'),
#  ('google', 'HCP'),
#  ('grainger', 'HCN'),
#  ('w.w.', 'HNZ'),
#  ('halliburton', 'HP'),
#  ('harley davidson', 'HES'),
#  ('harman international industries', 'HPQ'),
#  ('harrisoration', 'HD'),
#  ('hartford financial svc.gp.', 'HON'),
#  ('hasbro', 'HRL'),
#  ('hcp', 'HSP'),
#  ('health care reit', 'HST'),
#  ('heinz', 'HCBK'),
#  ('h.j.', 'HUM'),
#  ('helmerich and payne', 'HBAN'),
#  ('hessoration', 'ITW'),
#  ('hewlett packard', 'IR'),
#  ('home depot', 'TEG'),
#  ('honeywell international', 'INTC'),
#  ('hormel foods', 'ICE'),
#  ('hospira', 'IBM'),
#  ('host hotels and resorts', 'IFF'),
#  ('hudson city bancorp', 'IGT'),
#  ('humana', 'IP'),
#  ('huntington bancshares', 'IPG'),
#  ('illinois tool works', 'INTU'),
#  ('ingersoll rand plc', 'ISRG'),
#  ('integrys energy group', 'IVZ'),
#  ('intel', 'IRM'),
#  ('intercontinentalexchange', 'JBL'),
#  ('international bus machines', 'JEC'),
#  ('international flav/frag', 'JDSU'),
#  ('international game technology', 'JNJ'),
#  ('international paper', 'JCI'),
#  ('interpublic group', 'JOY'),
#  ('intuit', 'JPM'),
#  ('intuitive surgical', 'JNPR'),
#  ('invesco ltd.', 'K'),
#  ('iron mountainorporated', 'KEY'),
#  ('jabil circuit', 'KMB'),
#  ('jacobs engineering group', 'KIM'),
#  ('jds uniphase', 'KMI'),
#  ('johnson and johnson', 'KLAC'),
#  ('johnsonntrols', 'KSS'),
#  ('joy global', 'KFT'),
#  ('jpmorgan chase', 'KR'),
#  ('juniper networks', 'LLL'),
#  ('kellogg', 'LH'),
#  ('keycorp', 'LRCX'),
#  ('kimberly-clark', 'LM'),
#  ('kimco realty', 'LEG'),
#  ('kinder morgan', 'LEN'),
#  ('kla-tencor', 'LUK'),
#  ('kohls', 'LXK'),
#  ('kraft foods', 'LIFE'),
#  ('kroger', 'LLY'),
#  ('l-3mmunications holdings', 'LTD'),
#  ('laboratory of america holding', 'LNC'),
#  ('lam research', 'LLTC'),
#  ('legg mason', 'LMT'),
#  ('leggett and platt', 'L'),
#  ('lennar', 'LO'),
#  ('leucadia national', 'LOW'),
#  ('lexmark international', 'LSI'),
#  ('life technologies', 'MTB'),
#  ('lilly and co', 'M'),
#  ('eli and co', 'MRO'),
#  ('limited brands', 'MPC'),
#  ('lincoln national', 'MAR'),
#  ('linear technology', 'MMC'),
#  ('lockheed martin', 'MAS'),
#  ('loews', 'MA'),
#  ('lorillard', 'MAT'),
#  ('lowes', 'MKC'),
#  ('lsioration', 'MCD'),
#  ('m&t bank', 'MHP'),
#  ('macys', 'MCK'),
#  ('marathon oil', 'MJN'),
#  ('marathon petroleum', 'MWV'),
#  ('marriott international', 'MDT'),
#  ('marsh and mclennan', 'MRK'),
#  ('masco', 'MET'),
#  ('mastercard', 'PCS'),
#  ('mattel', 'MCHP'),
#  ('mccormick and co', 'MU'),
#  ('mcdonalds', 'MSFT'),
#  ('mcgraw-hill', 'MOLX'),
#  ('mckesson', 'TAP'),
#  ('mead johnson', 'MON'),
#  ('meadwestvacooration', 'MNST'),
#  ('medtronic', 'MCO'),
#  ('merck and co', 'MS'),
#  ('metlife', 'MOS'),
#  ('metropcsmmunications', 'MSI'),
#  ('microchip technology', 'MUR'),
#  ('micron technology', 'MYL'),
#  ('microsoft', 'NBR'),
#  ('molex', 'NDAQ'),
#  ('molsonors brewingmpany', 'NOV'),
#  ('monsanto', 'NTAP'),
#  ('monster beverage', 'NFLX'),
#  ('moodys', 'NWL'),
#  ('morgan stanley', 'NFX'),
#  ('the mosaicmpany', 'NEM'),
#  ('motorola solutions', 'NWSA'),
#  ('murphy oil', 'NEE'),
#  ('mylan', 'NKE'),
#  ('nabors industries ltd.', 'NI'),
#  ('nasdaq omx group', 'NE'),
#  ('national oilwell varco', 'NBL'),
#  ('netapp', 'JWN'),
#  ('netflix', 'NSC'),
#  ('newell rubbermaid', 'NTRS'),
#  ('newfield exploration', 'NOC'),
#  ('newmont mining (hldg.)', 'NU'),
#  ('newsoration', 'NRG'),
#  ('nextera energy resources', 'NUE'),
#  ('nike', 'NVDA'),
#  ('nisource', 'NYX'),
#  ('noble', 'ORLY'),
#  ('noble energy', 'OXY'),
#  ('nordstrom', 'OMC'),
#  ('norfolk southern', 'OKE'),
#  ('northern trust', 'ORCL'),
#  ('northrop grumman', 'OI'),
#  ('northeast utilities', 'PCAR'),
#  ('nrg energy', 'PLL'),
#  ('nucor', 'PH'),
#  ('nvidiaoration', 'PDCO'),
#  ('nyse euronext', 'PAYX'),
#  ('o reilly automotive', 'BTU'),
#  ('occidental petroleum', 'JCP'),
#  ('omnicom group', 'PBCT'),
#  ('oneok', 'POM'),
#  ('oracle', 'PEP'),
#  ('owens-illinois', 'PKI'),
#  ('paccar', 'PRGO'),
#  ('pall', 'PFE'),
#  ('parker-hannifin', 'PCG'),
#  ('pattersonmpanies', 'PM'),
#  ('paychex', 'PSX'),
#  ('peabody energy', 'PNW'),
#  ('penney (j.c.)', 'PXD'),
#  ('peoples united bank', 'PBI'),
#  ('pepco holdings', 'PCL'),
#  ('pepsico', 'PNC'),
#  ('perkinelmer', 'RL'),
#  ('perrigo', 'PPG'),
#  ('pfizer', 'PPL'),
#  ('pg&e', 'PX'),
#  ('philip morris international', 'PCP'),
#  ('phillips 66', 'PCLN'),
#  ('pinnacle west capital', 'PFG'),
#  ('pioneer natural resources', 'PG'),
#  ('pitney-bowes', 'PGR'),
#  ('plum creek timber', 'PLD'),
#  ('pnc financial services', 'PRU'),
#  ('polo ralph lauren', 'PEG'),
#  ('ppg industries', 'PSA'),
#  ('ppl', 'PHM'),
#  ('praxair', 'QEP'),
#  ('precision castparts', 'PWR'),
#  ('priceline.com', 'QCOM'),
#  ('principal financial group', 'DGX'),
#  ('procter & gamble', 'RRC'),
#  ('progressive', 'RTN'),
#  ('prologis', 'RHT'),
#  ('prudential financial', 'RF'),
#  ('public serv. enterprise', 'RSG'),
#  ('public storage', 'RAI'),
#  ('pulte homes', 'RHI'),
#  ('qep resources', 'ROK'),
#  ('quanta services', 'COL'),
#  ('qualcomm', 'ROP'),
#  ('quest diagnostics', 'ROST'),
#  ('range resources', 'RDC'),
#  ('raytheon', 'R'),
#  ('red hat', 'SWY'),
#  ('regions financial', 'SAI'),
#  ('republic services', 'CRM'),
#  ('reynolds american', 'SNDK'),
#  ('robert half international', 'SCG'),
#  ('rockwell automation', 'SLB'),
#  ('rockwellllins', 'SNI'),
#  ('roper industries', 'STX'),
#  ('ross stores', 'SEE'),
#  ('rowans.', 'SHLD'),
#  ('ryder system', 'SRE'),
#  ('safeway', 'SHW'),
#  ('saic', 'SIAL'),
#  ('salesforce.com', 'SPG'),
#  ('sandiskoration', 'SLM'),
#  ('scana', 'SJM'),
#  ('schlumberger ltd.', 'SNA'),
#  ('scripps networks interactive', 'SO'),
#  ('seagate technology', 'LUV'),
#  ('sealed air(new)', 'SWN'),
#  ('sears holdingsoration', 'SE'),
#  ('sempra energy', 'S'),
#  ('sherwin-williams', 'STJ'),
#  ('sigma-aldrich', 'SWK'),
#  ('simon property group', 'SPLS'),
#  ('slmoration', 'SBUX'),
#  ('smucker', 'HOT'),
#  ('snap-on', 'STT'),
#  ('southern', 'SRCL'),
#  ('southwest airlines', 'SYK'),
#  ('southwestern energy', 'SUN'),
#  ('spectra energy', 'STI'),
#  ('sprint nextel', 'SYMC'),
#  ('st jude medical', 'SYY'),
#  ('stanley black & decker', 'TROW'),
#  ('staples', 'TGT'),
#  ('starbucks', 'TEL'),
#  ('starwood hotels & resorts', 'TE'),
#  ('state street', 'THC'),
#  ('stericycle', 'TDC'),
#  ('stryker', 'TER'),
#  ('sunoco', 'TSO'),
#  ('suntrust banks', 'TXN'),
#  ('symantec', 'TXT'),
#  ('sysco', 'HSY'),
#  ('t. rowe price group', 'TRV'),
#  ('target', 'TMO'),
#  ('tennectivity ltd', 'TIF'),
#  ('teco energy', 'TWX'),
#  ('tenet healthcare', 'TWC'),
#  ('teradata', 'TIE'),
#  ('teradyne', 'TJX'),
#  ('tesoro petroleum', 'TMK'),
#  ('texas instruments', 'TSS'),
#  ('textron', 'TRIP'),
#  ('the hersheympany', 'TSN'),
#  ('the travelersmpanies', 'TYC'),
#  ('thermo fisher scientific', 'USB'),
#  ('tiffany and co', 'UNP'),
#  ('time warner', 'UNH'),
#  ('time warner cable', 'UPS'),
#  ('titanium metals', 'X'),
#  ('tjxmpanies', 'UTX'),
#  ('torchmark', 'UNM'),
#  ('total system services', 'URBN'),
#  ('tripadvisor', 'VFC'),
#  ('tyson foods', 'VLO'),
#  ('tyco international', 'VAR'),
#  ('u.s. bancorp', 'VTR'),
#  ('union pacific', 'VRSN'),
#  ('united health group', 'VZ'),
#  ('united parcel service', 'VIAB'),
#  ('united states steel', 'V'),
#  ('united technologies', 'VNO'),
#  ('unum group', 'VMC'),
#  ('urban outfitters', 'WMT'),
#  ('v.f.', 'WAG'),
#  ('valero energy', 'DIS'),
#  ('varian medical systems', 'WPO'),
#  ('ventas', 'WM'),
#  ('verisign', 'WAT'),
#  ('verizonmmunications', 'WPI'),
#  ('viacom', 'WLP'),
#  ('visa', 'WFC'),
#  ('vornado realty trust', 'WDC'),
#  ('vulcan materials', 'WU'),
#  ('wal-mart stores', 'WY'),
#  ('walgreen', 'WHR'),
#  ('disney', 'WFM'),
#  ('washington post', 'WMB'),
#  ('waste management', 'WIN'),
#  ('watersoration', 'WEC'),
#  ('watson pharmaceuticals', 'WPX'),
#  ('wellpoint', 'WYN'),
#  ('wells fargo', 'WYNN'),
#  ('western digital', 'XEL'),
#  ('western union', 'XRX'),
#  ('weyerhaeuser', 'XLNX'),
#  ('whirlpool', 'XL'),
#  ('whole foods market', 'XYL'),
#  ('williamss', 'YHOO'),
#  ('windstreamoration', 'YUM'),
#  ('wisconsin energyoration', 'ZMH'),
#  ('wpx energy', 'ZION')]

# %%
for a,b in insert:
    s.new_company(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-18aa9e11f57f> in <module>()
#       1 for a,b in insert:
# ----> 2     s.new_company(a,b)
#
# TypeError: new_company() missing 2 required positional arguments: 'time1' and 'time2'
